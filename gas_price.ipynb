# %% [markdown]
# <a href="https://colab.research.google.com/github/ProsperChuks/supreme-octo-umbrella/blob/main/gas_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Line Graph

# %%
gas = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/matplotlib/gas_prices.csv')

plt.figure(figsize=(7,5), dpi=150)

plt.title('Gas Prices over Time (in USD)')

plt.plot(gas.Year, gas.USA, label='United States')
plt.plot(gas.Year, gas.Canada, label='Canada')
plt.plot(gas.Year, gas['South Korea'], label='South Korea')

thrd_yr = gas.Year[::3]

plt.xticks(thrd_yr)

plt.legend()

plt.show()
