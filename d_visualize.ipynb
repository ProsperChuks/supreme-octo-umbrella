# %% [markdown]
# <a href="https://colab.research.google.com/github/ProsperChuks/supreme-octo-umbrella/blob/main/d_visualize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Basic Graph

# %%
x = np.array([0,1,2,3,4])
y = np.array([0,2,4,6,8])

plt.figure(figsize=[5,3], dpi=100)

# Line 1
# shorthand [color][marker][line]
plt.plot(x,y, 'g.--', label='2x', markersize=10)

# Line 2
# select interval to plot points at
x2 = np.arange(0,4.5,0.5)

# plot part of the graph as line
plt.plot(x2[:5], x2[:5]**2, 'r-', label='X^2')
# plt graph remainder as dot
plt.plot(x2[4:], x2[4:]**2, 'r--')

plt.title('Basic Graph')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')

plt.xticks([0,1,2,3,4])
# plt.yticks([0,2,4,6,8,10])
plt.legend()

plt.savefig('/content/drive/MyDrive/Colab Notebooks/matplotlib/random.png', dpi=300)

plt.show()

# %% [markdown]
# Bar Chart

# %%
labels = np.array(['A', 'B', 'C'])
values = np.array([1,4,6])

bars = plt.bar(labels, values)

patterns = ['*', 'O', '/']

for bar in bars:
  bar.set_hatch(patterns.pop())

plt.savefig('/content/drive/MyDrive/Colab Notebooks/matplotlib/bar.png', dpi=200)

plt.show()
