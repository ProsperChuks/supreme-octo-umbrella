# %% [markdown]
# <a href="https://colab.research.google.com/github/ProsperChuks/supreme-octo-umbrella/blob/main/FIFA_2019_data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

text_kwargs = dict(fontsize=24)
fifa = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/matplotlib/fifa_data.csv')
fifa.head(5)
# Out:
#    Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0           0  158023  ...        8.0         €226.5M
# 1           1   20801  ...       11.0         €127.1M
# 2           2  190871  ...       11.0         €228.1M
# 3           3  193080  ...       94.0         €138.6M
# 4           4  192985  ...       13.0         €196.4M
#
# [5 rows x 89 columns]

# %% [markdown]
# ### **Histogram**

# %%
bin = np.array([40,50,60,70,80,90,100])

plt.figure(figsize=(10,5))

plt.hist(fifa.Overall, bins=bin, color='red')

plt.xticks(bin)
plt.ylabel('Number of Players')
plt.xlabel('Skill level')
plt.title('Distribution of Player Skills in FIFA 19', **text_kwargs)

plt.savefig('/content/drive/MyDrive/Colab Notebooks/matplotlib/fifa_overall hist.png')

plt.show()

# %% [markdown]
# ### **Pie Chart**

# %%
fifa.head(10)

left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
right= fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]

plt.figure(figsize=(10,9))

labels = 'Left', 'Right'
explode = (0, 0.1)

plt.pie([left, right], explode=explode, labels=name,
        shadow=True, autopct='%.2f%%')

plt.title('Foot Preference of FIFA Players', **text_kwargs)
plt.legend()

plt.savefig('/content/drive/MyDrive/Colab Notebooks/matplotlib/foot_preference.png')

plt.show()

# %%
fifa.Weight = [int(x.strip('lbs')) if type(x) == str else x for x in fifa.Weight]

light = fifa.loc[fifa.Weight < 125].count()[0]
light_medium = fifa.loc[(fifa.Weight >= 125) & (fifa.Weight <= 150)].count()[0]
medium = fifa.loc[(fifa.Weight >= 150) & (fifa.Weight <= 175)].count()[0]
medium_heavy = fifa.loc[(fifa.Weight >= 175) & (fifa.Weight <= 200)].count()[0]
heavy = fifa.loc[fifa.Weight > 200].count()[0]

plt.figure(figsize=(10,9))

plt.style.use('ggplot')

labels = 'Under 125', '125-150', '150-175', '175-200', 'Over 200'
explode = (0.1, 0, 0, 0.1, 0)

plt.pie([light, light_medium, medium, medium_heavy, heavy], labels=labels,
        explode=explode, shadow=True, autopct='%.2f%%')

plt.title('Player\'s Weight(lbs)', **text_kwargs)

plt.show()
